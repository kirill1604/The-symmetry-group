# %% [markdown]
# ![methods](../../img/image.png)

# %% [markdown]
# # libs init

# %%
import numpy as np
import pandas as pd
from sklearn.feature_selection import VarianceThreshold

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Descriptors
from rdkit.Chem import DataStructs
from rdkit.Chem import MACCSkeys
from mordred import Calculator, descriptors
from padelpy import padeldescriptor

# %% [markdown]
# # Загрузка предобработанного датасета

# %%
# путь к файлу, полученному в мини-таске 1/4

# 1
# path = '../../data/target_cox2_IC50__preprocessed_aggregated.csv'

# 4
path = '../../data/new_molecules__target_cox2_pIC50__smiles.csv'
df = pd.read_csv(path)
df
# Out:
#                                                Smiles
# 0   C#CCCCC(=O)c1cc2c(c(C(=O)CCCC#C)c1)O[C@H](C(=O...
# 1   C/C(=N\NC(N)=S)c1nnn(C2Oc3ccc(S(F)(F)(F)(F)F)c...
# 2   C=C1C(=O)O[C@@H]2[C@H]1[C@@H](c1cc(O)cc(Br)c1O...
# 3              CC(=O)N1NC(c2ccccc2)=CC1c1nccc2ccccc12
# 4                               CC(C(=O)O)=C(C)C(=O)O
# 5   CC1=C(c2ccc(N3CC(C)N=C3c3cccc(Br)c3)cn2)SC2Nc3...
# 6                                         CCCCC=CCCCC
# 7                          CCCCCCCCCCCCCc1ccc(C)cc1Cl
# 8                              CN(C(=O)CCCl)C(=O)CCCl
# 9   COC1c2c(C34CC5CC(CC(C5)C3)C4)c(C34CC5CC(CC(C5)...
# 10  CS(=O)(=O)Nn1c(-c2ccc(Cl)cc2)nc2sc(-c3ccc(Cl)c...
# 11          CS(=O)(=O)c1ccc(-c2ccc(S(C)(=O)=O)cc2)cc1
# 12  CS(=O)(=O)c1ccc(C2=C(c3ccc(-c4cc([C@H]5OC(O)[C...
# 13                 C[C@H]1C[C@H]1c1ccc(S(C)(=O)=O)cc1
# 14  C[C@](O)(CCC=CCC[C@](C)(O)[C@@H]1CCC[C@]1(C)O)...
# 15  C[C@]1(c2cccc3cnccc23)OC(=O)C(Oc2ccc3c(c2)CCC3...
# 16  C[C@]12CCC3=C(COC3=O)[C@@H]1C[C@@H]1O[C@@]13[C...
# 17  Cc1cc(-c2ccc(F)c(Cl)c2)cc2c1O[C@H](c1ccc(F)c(C...
# 18  Cc1cc(C(=O)CC(C(=O)O)=C(CC(=O)c2cc(C)c3c(c2)OC...
# 19  Cc1cc2c(c(C)c1Cl)C=C(C(=O)O)[C@@H](CC(C)(C)C(=...
# 20           Cc1ccc(-n2c3ccccc3c(=O)c3ccccc32)c(Cl)c1
# 21  Cc1ccc(C2=NN(C3=NC(=O)CS3)C(OC3=C(c4ccc(S(C)(=...
# 22                     Cc1ccc(CCC2=CC(=O)OC2O)c(Cl)c1
# 23  Cc1cccc(-c2cc3occc3c(-c3cccc(C)c3)c2-c2cccc(C)...
# 24                           Cc1cnc(-c2ccc(Br)cc2F)s1
# 25  Clc1ccc2[nH]c3cc(-c4ccc5c(c4)[nH]c4ccc(Cl)cc45...
# 26      Fc1cc(-c2cc(Cl)cc(Cl)c2)ccc1-c1cc(Cl)cc(Cl)c1
# 27                          Fc1cccc(F)c1-c1c(F)cccc1F
# 28  N#Cc1c(/N=C/c2cccnc2)c(-c2c(/N=C/c3cccnc3)c(C#...
# 29          NC(N)=NC1=NC(=O)C(=C2OC(N=C(N)N)=NC2=O)O1
# 30  NS(=O)(=O)c1ccc(C2=C(c3ccc(-c4ccc(C5=C(c6ccc(S...
# 31  NS(=O)(=O)c1ccc(C2=C(c3ccc(-c4ccc(C5=C(c6ccc(S...
# 32  NS(=O)(=O)c1ccc(N2N=C3c4ccccc4CCC3C2CN2C(=O)C(...
# 33  Nc1nn2c(-c3cc(-c4ccn[nH]4)cc4c3O[C@@H](c3ccn[n...
# 34  O=C(c1ccc2c(c1)CCCS2)n1c(-c2ccc3c(c2)CCCS3)c(-...
# 35                        O=C1NC(=S)SC1=C1SC(=S)NC1=O
# 36  O=[N+]([O-])c1ccc2c(c1)S(=O)(=O)N=S2c1ccc(-c2c...
# 37  O=c1c([C@H]2Oc3cc(O)cc(O)c3C[C@H]2O)coc2ccc(Br...
# 38  c1ccc2c(c1)c1ccccc1n2-c1cn2c(c1-c1cn3c(c1-n1c4...
# 39                    c1ccc2ncc(-c3cnc4ccccc4c3)cc2c1
# 40                      c1ccc2sc(-c3cc4ccccc4s3)cc2c1
# 41                            n1nc(-c2nn[nH]n2)n[nH]1

# %% [markdown]
# # Преобразование SMILES → молекулы RDKit

# %%
df['Mol'] = df['Smiles'].apply(Chem.MolFromSmiles)
df = df[df['Mol'].notna()].reset_index(drop=True)
print(f"После фильтрации по валидным молекулам: {df.shape[0]} строк")
# Out:
# После фильтрации по валидным молекулам: 42 строк

# %% [markdown]
# # Расчёт 2D-дескрипторов RDKit

# %%
desc_list = Descriptors._descList	# список (name, function)

def rdkit2d(mol):
    vals = {}
    for name, func in desc_list:
        try:
            vals[name] = func(mol)
        except:
            vals[name] = np.nan
    return vals

rdkit_desc = df['Mol'].apply(rdkit2d).apply(pd.Series)
print(f"RDKit 2D-дескрипторов: {rdkit_desc.shape[1]}")
# Out:
# RDKit 2D-дескрипторов: 217

# %% [markdown]
# # Генерация Morgan fingerprints

# %%
def morgan_fp(mol, radius=2, nBits=1024):
    arr = np.zeros((nBits,), dtype=int)
    fp = AllChem.GetMorganFingerprintAsBitVect(mol, radius, nBits=nBits)
    

    DataStructs.ConvertToNumpyArray(fp, arr)
    return arr

# %% [markdown]
# ## ECFP4 (radius=2)

# %%
ecfp4_arr = np.stack(df['Mol'].apply(lambda m: morgan_fp(m, radius=2, nBits=1024)).values)
ecfp4_cols = [f'ECFP4_{i}' for i in range(ecfp4_arr.shape[1])]
ecfp4_df   = pd.DataFrame(ecfp4_arr, columns=ecfp4_cols, index=df.index)
print(f"ECFP4 bits: {ecfp4_df.shape[1]}")
# Out:
# ECFP4 bits: 1024
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator

# %% [markdown]
# ## ECFP6 (radius=3)

# %%
ecfp6_arr = np.stack(df['Mol'].apply(lambda m: morgan_fp(m, radius=3, nBits=1024)).values)
ecfp6_cols = [f'ECFP6_{i}' for i in range(ecfp6_arr.shape[1])]
ecfp6_df   = pd.DataFrame(ecfp6_arr, columns=ecfp6_cols, index=df.index)
print(f"ECFP6 bits: {ecfp6_df.shape[1]}")
# Out:
# ECFP6 bits: 1024
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator
# [20:47:51] DEPRECATION WARNING: please use MorganGenerator

# %% [markdown]
# # Генерация MACCS fingerprints

# %%
def maccs_fp(mol):
    fp  = MACCSkeys.GenMACCSKeys(mol)
    arr = np.zeros((fp.GetNumBits(),), dtype=int)
    DataStructs.ConvertToNumpyArray(fp, arr)
    return arr[1:]

maccs_arr = np.stack(df['Mol'].apply(maccs_fp).values)
maccs_cols = [f'MACCS_{i+1}' for i in range(maccs_arr.shape[1])]
maccs_df   = pd.DataFrame(maccs_arr, columns=maccs_cols, index=df.index)
print(f"MACCS bits: {maccs_df.shape[1]}")
# Out:
# MACCS bits: 166

# %% [markdown]
# # Расчёт 2D-дескрипторов Mordred

# %%
calc = Calculator(descriptors, ignore_3D=True)
mordred_desc = calc.pandas(df['Mol'])
print(f"Mordred-дескрипторов (2D): {mordred_desc.shape[1]}")
# Out:
# 100%|██████████| 42/42 [00:19<00:00,  2.13it/s]
# o:\Sync\_\DataCon_DD2025\.venv\lib\site-packages\numpy\core\fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# o:\Sync\_\DataCon_DD2025\.venv\lib\site-packages\numpy\core\fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# Mordred-дескрипторов (2D): 1613

# %% [markdown]
# # Расчёт дескрипторов PaDEL (CDK, PubChem, MACCS, ECFP)

# %%
SMI_FILE = '../../data/padel_input.smi'
PAD_OUT  = '../../data/padel_output.csv'
df[['Smiles']].to_csv(SMI_FILE, index=False, header=False)

padeldescriptor(
    mol_dir=SMI_FILE,
    d_file=PAD_OUT,
    fingerprints=True,
    threads=4
)

padel_df = pd.read_csv(PAD_OUT)
padel_df.index = df.index
padel_df = padel_df.drop(columns=['Name'], errors='ignore')
print(f"PaDEL-признаков: {padel_df.shape[1]}")
# Out:
# PaDEL-признаков: 881

# %% [markdown]
# # Объединение дескрипторов и fingerprint’ов

# %%
X = pd.concat([
    # df[['Smiles','Molecule ChEMBL ID','pIC50']],
	df[['Smiles']],
    rdkit_desc,
    ecfp4_df,
    ecfp6_df,
    maccs_df,
    mordred_desc,
    padel_df
], axis=1)
print(f"Признаков до фильтрации: {X.shape[1]-3}")
# Out:
# Признаков до фильтрации: 4923

# %% [markdown]
# # Фильтрация и отбор признаков
#
# - Удаление пропусков
# - Удаление признаков с нулевой дисперсией
# - Фильтрация признаков с высокой корреляцией (|r|>0.7) —> оставляем одну из пары

# %%
# 10.1 Удаляем колонки с NaN
X = X.dropna(axis=1, how='any')


# Удаляем низкую дисперсию
# vt = VarianceThreshold(threshold=1e-6)
vt = VarianceThreshold(threshold=0.0)
# core = X.drop(columns=['Smiles','Molecule ChEMBL ID','pIC50'])
core = X.drop(columns=['Smiles'])
vt.fit(core)
core = core.loc[:, vt.get_support()]

# X_filtered = pd.concat([X[['Smiles','Molecule ChEMBL ID','pIC50']], core], axis=1)
X_filtered = pd.concat([X[['Smiles']], core], axis=1)
print(f"После удаления признаков с низкой дисперсией: {core.shape[1]}")


# Удаляем скоррелированные признаки (|r| > 0.7)
corr  = core.corr().abs()
upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
to_drop = [c for c in upper.columns if any(upper[c] > 0.7)]

X_final = X_filtered.drop(columns=to_drop)
print(f"Удалено скоррелированных: {len(to_drop)}")
print(f"Итоговых признаков: {X_final.shape[1]-3}")
# Out:
# o:\Sync\_\DataCon_DD2025\.venv\lib\site-packages\sklearn\feature_selection\_variance_threshold.py:114: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   self.variances_ = np.nanvar(X, axis=0)
# o:\Sync\_\DataCon_DD2025\.venv\lib\site-packages\sklearn\feature_selection\_variance_threshold.py:122: RuntimeWarning: All-NaN slice encountered
#   self.variances_ = np.nanmin(compare_arr, axis=0)
# После удаления признаков с низкой дисперсией: 3492
# Удалено скоррелированных: 3105
# Итоговых признаков: 385

# %% [markdown]
# # Сохранение готового датасета

# %%
X_final
# Out:
#                                                Smiles  MaxAbsEStateIndex  \
# 0   C#CCCCC(=O)c1cc2c(c(C(=O)CCCC#C)c1)O[C@H](C(=O...          12.998950
# 1   C/C(=N\NC(N)=S)c1nnn(C2Oc3ccc(S(F)(F)(F)(F)F)c...          13.126592
# 2   C=C1C(=O)O[C@@H]2[C@H]1[C@@H](c1cc(O)cc(Br)c1O...          12.885088
# 3              CC(=O)N1NC(c2ccccc2)=CC1c1nccc2ccccc12          12.145024
# 4                               CC(C(=O)O)=C(C)C(=O)O          10.123981
# 5   CC1=C(c2ccc(N3CC(C)N=C3c3cccc(Br)c3)cn2)SC2Nc3...           4.895070
# 6                                         CCCCC=CCCCC           2.318611
# 7                          CCCCCCCCCCCCCc1ccc(C)cc1Cl           6.262946
# 8                              CN(C(=O)CCCl)C(=O)CCCl          11.036874
# 9   COC1c2c(C34CC5CC(CC(C5)C3)C4)c(C34CC5CC(CC(C5)...           6.423192
# 10  CS(=O)(=O)Nn1c(-c2ccc(Cl)cc2)nc2sc(-c3ccc(Cl)c...          13.121524
# 11          CS(=O)(=O)c1ccc(-c2ccc(S(C)(=O)=O)cc2)cc1          11.369011
# 12  CS(=O)(=O)c1ccc(C2=C(c3ccc(-c4cc([C@H]5OC(O)[C...          11.887051
# 13                 C[C@H]1C[C@H]1c1ccc(S(C)(=O)=O)cc1          11.193983
# 14  C[C@](O)(CCC=CCC[C@](C)(O)[C@@H]1CCC[C@]1(C)O)...          10.775131
# 15  C[C@]1(c2cccc3cnccc23)OC(=O)C(Oc2ccc3c(c2)CCC3...          13.434024
# 16  C[C@]12CCC3=C(COC3=O)[C@@H]1C[C@@H]1O[C@@]13[C...          12.622033
# 17  Cc1cc(-c2ccc(F)c(Cl)c2)cc2c1O[C@H](c1ccc(F)c(C...          13.547135
# 18  Cc1cc(C(=O)CC(C(=O)O)=C(CC(=O)c2cc(C)c3c(c2)OC...          12.864874
# 19  Cc1cc2c(c(C)c1Cl)C=C(C(=O)O)[C@@H](CC(C)(C)C(=...          11.564732
# 20           Cc1ccc(-n2c3ccccc3c(=O)c3ccccc32)c(Cl)c1          12.764228
# 21  Cc1ccc(C2=NN(C3=NC(=O)CS3)C(OC3=C(c4ccc(S(C)(=...          14.833935
# 22                     Cc1ccc(CCC2=CC(=O)OC2O)c(Cl)c1          10.902135
# 23  Cc1cccc(-c2cc3occc3c(-c3cccc(C)c3)c2-c2cccc(C)...           5.917279
# 24                           Cc1cnc(-c2ccc(Br)cc2F)s1          13.482079
# 25  Clc1ccc2[nH]c3cc(-c4ccc5c(c4)[nH]c4ccc(Cl)cc45...           6.176225
# 26      Fc1cc(-c2cc(Cl)cc(Cl)c2)ccc1-c1cc(Cl)cc(Cl)c1          14.533849
# 27                          Fc1cccc(F)c1-c1c(F)cccc1F          13.322819
# 28  N#Cc1c(/N=C/c2cccnc2)c(-c2c(/N=C/c3cccnc3)c(C#...          10.160923
# 29          NC(N)=NC1=NC(=O)C(=C2OC(N=C(N)N)=NC2=O)O1          11.538017
# 30  NS(=O)(=O)c1ccc(C2=C(c3ccc(-c4ccc(C5=C(c6ccc(S...          15.871531
# 31  NS(=O)(=O)c1ccc(C2=C(c3ccc(-c4ccc(C5=C(c6ccc(S...          15.553366
# 32  NS(=O)(=O)c1ccc(N2N=C3c4ccccc4CCC3C2CN2C(=O)C(...          12.946518
# 33  Nc1nn2c(-c3cc(-c4ccn[nH]4)cc4c3O[C@@H](c3ccn[n...          12.433910
# 34  O=C(c1ccc2c(c1)CCCS2)n1c(-c2ccc3c(c2)CCCS3)c(-...          15.168101
# 35                        O=C1NC(=S)SC1=C1SC(=S)NC1=O          11.310018
# 36  O=[N+]([O-])c1ccc2c(c1)S(=O)(=O)N=S2c1ccc(-c2c...          12.547696
# 37  O=c1c([C@H]2Oc3cc(O)cc(O)c3C[C@H]2O)coc2ccc(Br...          12.800637
# 38  c1ccc2c(c1)c1ccccc1n2-c1cn2c(c1-c1cn3c(c1-n1c4...           2.575217
# 39                    c1ccc2ncc(-c3cnc4ccccc4c3)cc2c1           4.509826
# 40                      c1ccc2sc(-c3cc4ccccc4s3)cc2c1           2.296343
# 41                            n1nc(-c2nn[nH]n2)n[nH]1           3.626481
#
#     MinEStateIndex       qed        SPS     MolWt  MinPartialCharge  \
# 0        -1.377580  0.269472  13.794118   458.510         -0.477762
# 1        -9.970684  0.245493  18.531250   498.459         -0.477718
# 2        -0.738483  0.394922  38.333333   435.314         -0.507909
# 3        -0.232587  0.784360  16.791667   315.376         -0.294749
# 4        -1.194537  0.552910  12.200000   144.126         -0.477871
# 5         0.193122  0.463681  21.531250   504.457         -0.354446
# 6         1.277990  0.387226  11.000000   140.270         -0.088539
# 7         0.946370  0.350520  11.000000   308.937         -0.084031
# 8        -0.263781  0.656922   9.583333   212.076         -0.285701
# 9         0.200286  0.468886  50.363636   447.707         -0.374592
# 10       -3.721469  0.476777  11.689655   466.371         -0.266581
# 11       -3.207159  0.870961  12.300000   310.396         -0.223991
# 12       -3.254336  0.383683  28.710526   539.606         -0.387380
# 13       -3.038400  0.749680  26.142857   210.298         -0.223991
# 36  0.938255                                           0.950582  0.265264
# 37  1.120408                                             1.2172  0.928299
# 38  1.167111                                           1.124689  0.974457
# 39  1.030649                                           1.074667  0.732222
# 40  1.166667                                           0.461538  0.642246
# 41  0.000000  invalid value encountered in scalar divide (GA...  0.851837
#
#      GATS5se  BCUTdv-1l  BCUTd-1l  NdsCH     SdssC
# 0   1.193142   1.856630  0.910541      1 -2.575788
# 1   0.925839   0.652905  0.971497      1 -1.925570
# 2   0.815930   0.256011  0.976209      0  0.013323
# 3   1.011518   0.995954  0.973009      1  0.877268
# 4   1.044928   0.994760  0.971501      0 -2.652963
# 5   1.096789   0.256008  0.992964      0  3.461614
# 6   0.938235   0.987144  0.987144      2  0.000000
# 7   1.389308   0.773997  0.987730      0  0.000000
# 8   0.762033   0.767071  0.977289      0 -0.527562
# 9   1.169709   0.992254  0.987669      0  0.000000
# 10  0.769677   0.615883  0.968248      0  0.000000
# 11  0.791306   0.615542  0.966223      0  0.000000
# 12  0.798084   0.615882  0.968316      0  2.517611
# 13  0.829766   0.615884  0.968554      0  0.000000
# 14  1.297668   0.995015  0.991048      2  0.000000
# 15  1.389543   0.615882  0.968343      0  0.066871
# 16  1.040245   0.255079  0.977238      0  3.403137
# 17  0.573325   0.773075  0.972744      1 -1.182552
# 18  0.813961   0.995020  0.971522      0 -5.804740
# 19  1.121328   0.773993  0.971531      1 -2.089922
# 20  1.492619   0.774004  0.977873      0  0.000000
# 21  1.074193   0.615542  0.966223      1 -1.526861
# 22  1.190914   0.774005  0.977886      1  0.119578
# 23  0.830551   0.995015  0.992942      0  0.000000
# 24  1.323628   0.256014  0.992924      0  0.000000
# 25  0.571788   0.773072  0.992942      0  0.000000
# 26  1.308104   0.773060  0.992874      0  0.000000
# 27  1.129770   2.778648  0.992937      0  0.000000
# 28  1.460741   1.857150  0.910868      2  0.000000
# 29  1.594801   2.975333  0.977231      0 -4.449733
# 30  0.839236   0.641386  0.966223      0  4.210087
# 31  0.827319   0.641386  0.966223      0  4.001866
# 32  1.028618   0.642095  0.968285      0 -0.100188
# 33  0.849727   2.812422  0.972870      1 -1.117773
# 34  1.255419   0.655386  0.978071      0  0.054435
# 35  0.785042   0.649015  0.977110      0  0.728553
# 36  0.887947   0.641969  0.970018      0  0.000000
# 37  1.014356   0.256013  0.977805      0  0.000000
# 38  1.220008   1.857148  1.751600      0  0.000000
# 39  1.216719   2.751743  1.751239      0  0.000000
# 40  0.963603   0.652147  1.751531      0  0.000000
# 41  1.313549   3.857953  1.757913      0  0.000000
#
# [42 rows x 388 columns]

# %%
# OUT_CSV = '../../data/target_cox2_IC50__descriptors_with_ECFP6.csv'

# ДЛЯ НОВЫХ МОЛЕКУЛ
OUT_CSV = '../../data/new_molecules__target_cox2_pIC50__descriptors_with_ECFP6.csv'
X_final.to_csv(OUT_CSV, index=False)
print(f"Сохранено: {OUT_CSV}")
# Out:
# Сохранено: ../../data/new_molecules__target_cox2_pIC50__descriptors_with_ECFP6.csv
